# %%
import xarray as xr
import numpy as np
import os
from src.configs import ProjectConfigs, gSAMConfigs
from glob import glob

import matplotlib.pyplot as plt

# %%
d ='/glade/work/pangulo/gsam_dyamond_winter/northwest_tropical_pacific/2D_moisture_space_grids_50pix'
file = 'satfrac_sorted.lon_2.lat_4.northwest_tropical_pacific.DYAMOND2_9216x4608x74_10s_4608_20200215210000_0000232200.2D_atm.nc'
fn = d + f'/{file}'

# %%
os.path.isfile(fn)
# Out:
# True

# %%
da = xr.open_dataset(fn)

# %%
(da.PW/da.PWS).plot()

# %%
da.W.min()
# Out:
# <xarray.DataArray 'W' ()> Size: 4B
# array(-2.7907224, dtype=float32)

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(15, 5))

for i, ax in enumerate(axs.ravel()):
    circ = xr.open_dataarray(f'{ProjectConfigs().project_root_dir}/data/moisture_space_composite.W.phase{i+1}.northwest_tropical_pacific.nc').coarsen({'column': 5}).mean()
    circ.plot.contourf(ax=ax, levels=np.linspace(-150, 0, 20), cmap=plt.cm.jet)
    break
fig.tight_layout(pad=1.0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /glade/work/pangulo/conda-envs/dyamond/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /glade/work/pangulo/conda-envs/dyamond/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/glade/u/home/pangulo/multiscale_circulations_in_gsam/moisture_space_composite.W.phase1.northwest_tropical_pacific.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '5ac1cc7c-5b8a-4d49-ae3f-a9dbdccdd581']
#
# ...

# %%
circ.plot.contour()
